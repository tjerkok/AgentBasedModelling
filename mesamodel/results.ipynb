# %%
import matplotlib.pyplot as plt
import numpy as np
from load import local_SA, load_SA

# %%
data_more = load_SA("more_data.pkl")
data_less = load_SA("local_SA_data_speed2.pkl")["speed2"][2][1]

# %%
print(data_more, "\n")
print(data_less, "\n")
# Out:
# {'mean_interactions': [24.12807881773399, 24.385245901639344, 24.0, 25.69808306709265, 24.57443365695793, 22.525790349417637, 25.576329331046313, 28.463108320251177, 25.233390119250426, 27.71656050955414], 'mean_time_steps': [153.5878489326765, 160.99344262295082, 164.40344827586208, 164.21725239616615, 157.37540453074433, 152.67054908485858, 174.97084048027443, 170.72684458398743, 166.96592844974447, 168.09872611464968], 'mean_distance': [240.4105090311987, 239.00983606557378, 248.94137931034481, 243.93929712460064, 237.2766990291262, 229.4875207986689, 256.4271012006861, 246.2558869701727, 244.98977853492335, 245.77388535031847]}
#
# ...

# %%
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
fig3, ax3 = plt.subplots()
# data = data_avg_arrival["avg_arrival"]
print("avg arrival, interactions, timesteps, distance")

# more
interactions, time_steps, distance = [data_more["mean_interactions"]], [data_more["mean_time_steps"]], [data_more["mean_distance"]]
print(0, np.mean(interactions), np.mean(time_steps), np.mean(distance))
ax1.errorbar(0, np.mean(interactions), yerr=2*np.std(interactions), fmt="k.", ecolor="gray")
ax2.errorbar(0, np.mean(time_steps), yerr=2*np.std(time_steps), fmt="k.", ecolor="gray")
ax3.errorbar(0, np.mean(distance), yerr=2*np.std(distance), fmt="k.", ecolor="gray")

# less
interactions, time_steps, distance = [data_less["mean_interactions"]], [data_less["mean_time_steps"]], [data_less["mean_distance"]]
print(1, np.mean(interactions), np.mean(time_steps), np.mean(distance))
ax1.errorbar(1, np.mean(interactions), yerr=2*np.std(interactions), fmt="k.", ecolor="gray")
ax2.errorbar(1, np.mean(time_steps), yerr=2*np.std(time_steps), fmt="k.", ecolor="gray")
ax3.errorbar(1, np.mean(distance), yerr=2*np.std(distance), fmt="k.", ecolor="gray")
    
ax1.set_ylabel("interactions")
ax1.set_xlabel("avg arrival rate")
ax2.set_ylabel("time steps")
ax2.set_xlabel("avg arrival rate")
ax3.set_ylabel("distance")
ax3.set_xlabel("avg arrival rate")
# fig1.savefig("figs/results_interactions")
# fig2.savefig("figs/results_timesteps")
# fig3.savefig("figs/results_distance")
# Out:
# avg arrival, interactions, timesteps, distance
# 0 25.230102007294363 163.40102854719146 243.25118934156134
# 1 32.45044572337204 196.05616146865628 287.8168949382489
